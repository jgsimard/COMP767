# %%
import numpy as np
import gluoncv
from matplotlib import pyplot as plt
import cv2

# %%
train_root = "/home/jg/MILA/COMP767-Reinforcement_Learning/COMP767/project/data/VOCtrainval_06-Nov-2007/VOCdevkit"
eval_root = "/home/jg/MILA/COMP767-Reinforcement_Learning/COMP767/project/data/VOCdevkit"

train_dataset = gluoncv.data.VOCDetection(root = train_root, splits=[(2007, 'trainval')])
val_dataset = gluoncv.data.VOCDetection(root = eval_root, splits=[(2007, 'test')])
print('Num of training images:', len(train_dataset))
print('Num of validation images:', len(val_dataset))
# Out:
# Num of training images: 5011
# Num of validation images: 4952

# %%
detected_class=14 #aeroplane
detected_class_name = train_dataset.classes[detected_class]
print(detected_class_name)
set_name = "trainval"
fname = f"{train_root}/VOC2007/ImageSets/Main/{detected_class_name}_{set_name}.txt"
with open(fname) as f:
    content = f.readlines()

content_index = [int(x.strip().split()[0]) for x in content]
content_detected_class = [int(x.strip().split()[0]) for x in content if int(x.strip().split()[1]) ==1] 
content_detected_class_filtered=[]
i = 0
for class_img_index in content_detected_class:
    while i < len(content_index):
        if content_index[i] == class_img_index:
            content_detected_class_filtered.append(i)
            break
        i+=1
print(content_detected_class)
print(content_detected_class_filtered)
# Out:
# person
# [9, 17, 21, 23, 30, 32, 35, 41, 48, 50, 66, 73, 81, 83, 89, 101, 104, 110, 113, 125, 129, 133, 138, 146, 150, 159, 162, 163, 164, 165, 169, 170, 171, 173, 174, 177, 192, 193, 194, 200, 210, 218, 220, 222, 229, 232, 245, 251, 257, 259, 269, 275, 276, 278, 282, 285, 288, 298, 302, 305, 308, 320, 321, 322, 323, 328, 331, 337, 338, 352, 359, 367, 372, 374, 382, 394, 407, 411, 419, 428, 433, 435, 438, 443, 446, 448, 463, 468, 470, 476, 477, 480, 482, 483, 498, 499, 500, 516, 518, 520, 523, 524, 525, 526, 530, 531, 535, 545, 554, 555, 579, 589, 591, 597, 612, 613, 625, 626, 633, 654, 677, 684, 688, 690, 694, 695, 702, 709, 717, 726, 731, 733, 739, 742, 750, 752, 753, 760, 770, 777, 782, 793, 797, 799, 802, 805, 806, 810, 812, 814, 816, 828, 829, 834, 843, 847, 848, 851, 854, 859, 860, 865, 874, 878, 879, 885, 892, 895, 898, 902, 903, 904, 906, 911, 915, 918, 920, 926, 943, 948, 949, 967, 971, 987, 991, 996, 999, 1001, 1011, 1014, 1017, 1024, 1028, 1036, 1042, 1050, 1057, 1060, 1061, 1064, 1066, 1071, 1072, 1079, 1084, 1091, 1097, 1101, 1109, 1113, 1125, 1129, 1137, 1140, 1145, 1147, 1151, 1152, 1164, 1168, 1170, 1171, 1175, 1185, 1186, 1201, 1206, 1212, 1221, 1224, 1229, 1234, 1236, 1240, 1241, 1248, 1254, 1259, 1265, 1266, 1269, 1272, 1279, 1284, 1287, 1292, 1298, 1304, 1309, 1310, 1311, 1315, 1325, 1327, 1330, 1333, 1337, 1346, 1350, 1352, 1362, 1388, 1390, 1393, 1405, 1406, 1408, 1409, 1414, 1420, 1421, 1426, 1427, 1430, 1434, 1445, 1450, 1451, 1455, 1460, 1472, 1475, 1479, 1480, 1485, 1493, 1498, 1499, 1501, 1504, 1509, 1510, 1514, 1521, 1523, 1524, 1526, 1531, 1532, 1536, 1537, 1544, 1548, 1554, 1557, 1561, 1563, 1571, 1577, 1579, 1580, 1586, 1593, 1594, 1603, 1608, 1611, 1617, 1622, 1627, 1628, 1630, 1640, 1649, 1651, 1654, 1678, 1682, 1686, 1689, 1690, 1691, 1711, 1717, 1721, 1723, 1725, 1726, 1729, 1730, 1749, 1754, 1756, 1758, 1759, 1766, 1772, 1775, 1784, 1785, 1789, 1793, 1795, 1797, 1799, 1800, 1801, 1806, 1807, 1809, 1810, 1828, 1830, 1832, 1833, 1836, 1837, 1841, 1843, 1849, 1854, 1861, 1864, 1887, 1894, 1899, 1902, 1903, 1904, 1918, 1920, 1927, 1930, 1932, 1938, 1941, 1944, 1945, 1950, 1958, 1963, 1977, 1978, 1980, 1989, 1999, 2000, 2012, 2022, 2024, 2030, 2051, 2055, 2061, 2069, 2082, 2090, 2091, 2096, 2104, 2108, 2114, 2117, 2120, 2142, 2145, 2156, 2163, 2169, 2170, 2171, 2172, 2174, 2176, 2183, 2186, 2187, 2190, 2193, 2194, 2213, 2214, 2219, 2220, 2221, 2224, 2226, 2233, 2238, 2241, 2244, 2256, 2261, 2265, 2272, 2273, 2277, 2285, 2290, 2293, 2302, 2306, 2307, 2311, 2324, 2329, 2332, 2337, 2342, 2361, 2362, 2367, 2372, 2378, 2382, 2384, 2385, 2387, 2401, 2403, 2405, 2410, 2413, 2419, 2425, 2433, 2443, 2444, 2448, 2450, 2458, 2459, 2460, 2472, 2476, 2477, 2481, 2483, 2491, 2501, 2504, 2514, 2518, 2520, 2524, 2533, 2539, 2540, 2542, 2545, 2554, 2555, 2558, 2561, 2563, 2564, 2565, 2572, 2584, 2585, 2589, 2595, 2611, 2613, 2625, 2632, 2633, 2636, 2637, 2641, 2643, 2649, 2657, 2658, 2662, 2668, 2669, 2675, 2678, 2689, 2691, 2693, 2710, 2713, 2714, 2715, 2723, 2727, 2730, 2735, 2741, 2744, 2751, 2755, 2759, 2767, 2776, 2786, 2795, 2798, 2803, 2804, 2807, 2815, 2826, 2827, 2834, 2838, 2841, 2842, 2855, 2858, 2859, 2864, 2867, 2870, 2879, 2881, 2884, 2886, 2889, 2899, 2912, 2913, 2914, 2915, 2916, 2931, 2932, 2933, 2935, 2939, 2940, 2954, 2958, 2960, 2962, 2965, 2975, 2976, 2987, 2988, 2990, 2992, 3002, 3003, 3017, 3023, 3024, 3027, 3034, 3039, 3042, 3044, 3057, 3058, 3063, 3064, 3065, 3077, 3078, 3086, 3088, 3089, 3100, 3102, 3106, 3107, 3118, 3121, 3122, 3124, 3129, 3134, 3138, 3140, 3145, 3147, 3150, 3159, 3162, 3170, 3175, 3181, 3185, 3188, 3189, 3205, 3210, 3213, 3218, 3228, 3236, 3247, 3253, 3259, 3260, 3261, 3270, 3280, 3282, 3284, 3290, 3292, 3296, 3301, 3303, 3311, 3313, 3320, 3327, 3335, 3344, 3355, 3360, 3362, 3367, 3369, 3373, 3376, 3380, 3382, 3386, 3390, 3391, 3395, 3396, 3397, 3403, 3406, 3407, 3412, 3416, 3417, 3422, 3424, 3429, 3433, 3435, 3436, 3450, 3453, 3455, 3462, 3465, 3466, 3468, 3469, 3470, 3484, 34 ...
# [2, 5, 8, 9, 12, 13, 16, 19, 24, 25, 33, 35, 38, 39, 40, 45, 47, 50, 52, 59, 60, 64, 66, 71, 73, 78, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 95, 96, 97, 99, 104, 108, 110, 112, 116, 117, 124, 128, 130, 131, 136, 138, 139, 140, 141, 142, 143, 147, 148, 151, 154, 159, 160, 161, 162, 164, 166, 170, 171, 177, 180, 182, 184, 186, 190, 193, 200, 202, 205, 209, 212, 213, 214, 216, 217, 218, 225, 227, 229, 231, 232, 233, 234, 235, 243, 244, 245, 253, 254, 256, 258, 259, 260, 261, 263, 264, 265, 271, 275, 276, 282, 287, 289, 291, 299, 300, 304, 305, 308, 315, 326, 329, 332, 334, 335, 336, 339, 342, 348, 350, 354, 355, 357, 359, 362, 363, 364, 368, 374, 379, 381, 385, 388, 389, 391, 393, 394, 396, 397, 398, 400, 407, 408, 412, 414, 416, 417, 420, 421, 424, 425, 428, 433, 435, 436, 439, 443, 444, 446, 449, 450, 451, 452, 454, 456, 458, 460, 463, 470, 473, 474, 483, 484, 490, 492, 494, 496, 497, 503, 505, 507, 509, 511, 512, 514, 517, 521, 522, 523, 525, 526, 529, 530, 535, 538, 539, 542, 543, 548, 551, 555, 557, 560, 561, 565, 566, 569, 570, 576, 578, 579, 580, 583, 587, 588, 595, 599, 603, 606, 607, 610, 614, 615, 618, 619, 621, 623, 625, 628, 629, 631, 633, 637, 639, 641, 645, 648, 650, 651, 652, 653, 656, 660, 662, 663, 665, 667, 671, 673, 674, 677, 688, 689, 690, 696, 697, 698, 699, 701, 703, 704, 705, 706, 707, 709, 716, 717, 718, 720, 722, 730, 731, 732, 733, 737, 742, 745, 746, 747, 748, 749, 750, 752, 755, 757, 758, 759, 762, 763, 764, 765, 769, 771, 773, 776, 778, 779, 781, 783, 784, 785, 787, 790, 791, 795, 798, 800, 803, 805, 806, 807, 808, 813, 817, 819, 821, 829, 831, 835, 837, 838, 839, 844, 847, 849, 850, 852, 853, 855, 856, 865, 868, 870, 871, 872, 875, 878, 879, 884, 885, 887, 888, 889, 890, 891, 892, 893, 894, 895, 896, 897, 903, 904, 905, 906, 908, 909, 911, 913, 916, 918, 922, 924, 932, 935, 938, 940, 941, 942, 947, 948, 950, 952, 954, 959, 961, 962, 963, 965, 968, 971, 977, 978, 979, 983, 985, 986, 992, 997, 999, 1002, 1012, 1014, 1017, 1022, 1024, 1028, 1029, 1032, 1037, 1038, 1041, 1043, 1044, 1055, 1056, 1062, 1064, 1067, 1068, 1069, 1070, 1071, 1072, 1078, 1080, 1081, 1082, 1085, 1086, 1095, 1096, 1099, 1100, 1101, 1102, 1103, 1105, 1108, 1109, 1110, 1117, 1121, 1123, 1128, 1129, 1131, 1137, 1140, 1142, 1144, 1146, 1147, 1150, 1156, 1158, 1160, 1164, 1166, 1176, 1177, 1180, 1184, 1190, 1191, 1192, 1193, 1194, 1198, 1199, 1201, 1203, 1205, 1208, 1211, 1213, 1220, 1221, 1223, 1224, 1228, 1229, 1230, 1238, 1239, 1240, 1244, 1245, 1247, 1254, 1256, 1261, 1262, 1264, 1266, 1269, 1272, 1273, 1274, 1276, 1280, 1281, 1282, 1284, 1285, 1286, 1287, 1292, 1295, 1296, 1298, 1302, 1310, 1311, 1315, 1317, 1318, 1321, 1322, 1323, 1324, 1329, 1331, 1332, 1334, 1338, 1339, 1341, 1343, 1348, 1350, 1351, 1360, 1361, 1362, 1363, 1368, 1369, 1370, 1373, 1376, 1377, 1381, 1382, 1384, 1390, 1394, 1401, 1404, 1406, 1409, 1410, 1411, 1414, 1418, 1419, 1421, 1424, 1425, 1426, 1432, 1433, 1434, 1435, 1437, 1440, 1443, 1445, 1446, 1447, 1448, 1452, 1456, 1457, 1458, 1459, 1460, 1464, 1465, 1466, 1468, 1471, 1472, 1481, 1484, 1485, 1486, 1488, 1492, 1493, 1498, 1499, 1501, 1502, 1506, 1507, 1516, 1518, 1519, 1520, 1524, 1526, 1527, 1528, 1535, 1536, 1538, 1539, 1540, 1544, 1545, 1549, 1550, 1551, 1557, 1558, 1561, 1562, 1568, 1570, 1571, 1572, 1575, 1577, 1580, 1581, 1583, 1585, 1587, 1591, 1593, 1598, 1599, 1603, 1606, 1608, 1609, 1616, 1618, 1620, 1623, 1626, 1630, 1636, 1638, 1643, 1644, 1645, 1648, 1654, 1655, 1656, 1658, 1659, 1662, 1665, 1666, 1669, 1670, 1672, 1674, 1677, 1683, 1688, 1691, 1692, 1695, 1696, 1698, 1700, 1703, 1704, 1705, 1706, 1707, 1709, 1710, 1711, 1714, 1716, 1717, 1720, 1723, 1724, 1728, 1729, 1731, 1733, 1734, 1735, 1741, 1744, 1745, 1748, 1750, 1751, 1752, 1753, 1754, 1756, 1757, 1760, 1762, 1772, 1774, 1778, 1779, 1780, 1783, 1785, 1787, 1791, 1794, 1795, 1796, 1797, 1798, 1799, 1800, 1804, 1810, 1816, 1818, 1820, 1823, 1825, 1831, 1835, 1836, 1838, 1839, 1840, 1841, 1846, 1847, 1848, 1850, 1855, 1859, 1860, 186 ...

# %%
train_image, train_label = train_dataset[2]
print('Image size (height, width, RGB):', train_image.shape)
# Out:
# Image size (height, width, RGB): (375, 500, 3)

# %%
bounding_boxes = train_label[:, :4]
print('Num of objects:', bounding_boxes.shape[0])
print('Bounding boxes (num_boxes, x_min, y_min, x_max, y_max):\n',  bounding_boxes)
# Out:
# Num of objects: 4
# Bounding boxes (num_boxes, x_min, y_min, x_max, y_max):
#  [[ 68. 171. 269. 329.]
#  [149. 140. 228. 283.]
#  [284. 200. 326. 330.]
#  [257. 197. 296. 328.]]

# %%
class_ids = train_label[:, 4]
print('Class IDs (num_boxes, ):\n', class_ids)
# Out:
# Class IDs (num_boxes, ):
#  [12. 14. 14. 14.]

# %%
gluoncv.utils.viz.plot_bbox(train_image.asnumpy(), bounding_boxes, 
                            scores=None,labels=class_ids, class_names=train_dataset.classes)
plt.show()

# %%
class BoundingBox:
    def __init__(self, x1, y1, x2, y2):
        self.x1 = x1
        self.y1 = y1
        self.x2 = x2
        self.y2 = y2

    def area(self):
        return (self.x2-self.x1) * (self.y2-self.y1)
    
    def __repr__(self):
        return f"(x1,y1)=({self.x1}, {self.y1}), (x2,y2)=({self.x2}, {self.y2})"

# %%
bb = BoundingBox(149, 140, 228, 283)
def add_ior(img, bb, f=5):
    w = bb.x2 - bb.x1
    h = bb.y2 - bb.y1
    delta_x = int(w*(1-1/f)/2)
    delta_y = int(h*(1-1/f)/2)
    cv2.rectangle(img,(bb.x1 + delta_x,bb.y1),(bb.x2 - delta_x,bb.y2),(0,0,0),-1)
    cv2.rectangle(img,(bb.x1,bb.y1 + delta_y),(bb.x2,bb.y2 - delta_y),(0,0,0),-1)
    
img = train_image.asnumpy()
gluoncv.utils.viz.plot_bbox(img, bounding_boxes, scores=None,labels=class_ids, class_names=train_dataset.classes)

add_ior(img, bb)
gluoncv.utils.viz.plot_bbox(img, bounding_boxes, scores=None, labels=class_ids, class_names=train_dataset.classes)
plt.show()
