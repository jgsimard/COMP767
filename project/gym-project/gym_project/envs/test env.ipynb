# %%
# %load_ext autoreload
# %autoreload 2

import gym 
import matplotlib.pyplot as plt

import object_localization

# %%
# env = gym.make('project-v0')
env = object_localization.ProjectEnv()

obs = env.reset()
plt.imshow(obs)
plt.show()
# Out:
# Environement initializatione done for class : person

# %%
print(env.action_index_to_names)
# Out:
# {0: 'right', 1: 'left', 2: 'up', 3: 'down', 4: 'bigger', 5: 'smaller', 6: 'fatter', 7: 'taller', 8: 'trigger'}

# %%
obs, reward, done, _ = env.step(action=8)
plt.imshow(obs)
plt.show()
print(reward)
# Out:
# 0.5243445692883895
# 3
