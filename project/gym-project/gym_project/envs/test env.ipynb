# %%
# %load_ext autoreload
# %autoreload 2

import gym 
import matplotlib.pyplot as plt

import object_localization

# %%
# env = gym.make('project-v0')
env = object_localization.ProjectEnv()

obs = env.reset()
plt.imshow(obs)
plt.show()
# Out:
# This environement is for person et JG!
# y1, y2, x1, x2 0 224 0 224
