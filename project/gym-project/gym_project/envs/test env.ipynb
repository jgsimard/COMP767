# %%
# %load_ext autoreload
# %autoreload 2

import gym 
import matplotlib.pyplot as plt

import object_localization

# %%
# env = gym.make('project-v0')
env = object_localization.ProjectEnv()

obs = env.reset()
plt.imshow(obs)
plt.show()
# Out:
# This environement is for person et JG!
# image.shape (375, 500, 3)
# label [[285. 141. 327. 270.   4.   0.]
#  [355. 156. 414. 302.   4.   0.]
#  [  1.  31. 269. 332.  14.   0.]
#  [  0.   2.  64.  78.  14.   0.]]
# scaled_label [[  0.  18. 120. 198.  14.   0.]
#  [  0.   1.  28.  46.  14.   0.]]
# y1, y2, x1, x2 0 224 0 224

# %%
obs, reward, done, _ = env.step(action=8)
plt.imshow(obs)
plt.show()
print(reward)
# Out:
# a_w:27, a_h:27, delta_x_right:27, delta_x_left:-17, delta_y_up:-27, delta_y_down:27
# new_bb (x1,y1)=(17, 44), (x2,y2)=(153, 180)
# y1, y2, x1, x2 0 224 0 224
# -3
